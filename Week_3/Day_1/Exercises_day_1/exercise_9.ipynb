# %% [markdown]
# Exercise 9 : Export a dataframe to excel format
# and JSON format
# ====
# - Create a simple dataframe.
#
# - Export the dataframe to an excel file.
#
# - Export the dataframe to a JSON file.

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = {
    'Name': ['Alme', 'Itay', 'Lancelot'],
    'Score': [95, 88, 100]
}

df_mydata = pd.DataFrame(data)

# %% [markdown]
# Creating an excel:

# %%
df_mydata.to_excel('my_exercise_data.xlsx', index=False)

print("Excel file created!")
# Out:
# Excel file created!

# %% [markdown]
# Creating a Json file:

# %%
df_mydata.to_json('my_exercise_data.json')

print("JSON file created!")
# Out:
# JSON file created!

# %%
print("Success! Check your sidebar for the new files.")
# Out:
# Success! Check your sidebar for the new files.
